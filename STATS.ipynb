# %%
import re
from collections import defaultdict

def extract_runs_wickets(text):
    runs = 0
    wicket = False
    
    # Check for runs scored
    run_patterns = [r'\b(\d+)\s+run', r'\b(\d+)\s+runs', r'(FOUR)\s+runs', r'(SIX)\s+runs', r'\b(\d+)\s+leg\s+bye']
    for pattern in run_patterns:
        match = re.search(pattern, text, re.IGNORECASE)
        if match:
            if match.lastindex == 3 and match.group(3).lower() == 'four':
                runs += 4
            elif match.lastindex == 4 and match.group(4).lower() == 'six':
                runs += 6
            elif match.group(1) and match.group(1).lower() not in ['four', 'six']:
                runs += int(match.group(1))
            elif match.group(1) and match.group(1).lower() not in ['four', 'six']:
                runs += int(match.group(1))
    
    # Check for wickets
    wicket_patterns = [r'\b(OUT)\b', r'\bcaught\s+and\s+bowled\b', r'\bcaught\s+behind\b', r'\bbowled\b', r'\blbw\b', r'\bstumped\b']
    for pattern in wicket_patterns:
        if re.search(pattern, text, re.IGNORECASE):
            wicket = True
            break
    
    return runs, wicket

# Define a function to extract batsman and bowler from the text
def extract_batsman_bowler(text):
    parts = text.split(',')
    bowler_batsman = parts[0].split('to')
    bowler = bowler_batsman[0].strip()
    batsman = bowler_batsman[1].strip()
    return bowler, batsman

def calculate_shots(data, batting_terms, bowling_terms):
    batsman_shots = defaultdict(list)
    bowler_shots = defaultdict(list)
    
    for _, row in data.iterrows():
        long_text = str(row['long_text']).lower()  # Convert to string first, then to lowercase
        for term in batting_terms:
            if term in long_text:
                bowler, batsman = extract_batsman_bowler(row['short_text'])
                batsman_shots[batsman].append(term)
        for term in bowling_terms:
            if term in long_text:
                bowler, batsman = extract_batsman_bowler(row['short_text'])
                bowler_shots[bowler].append(term)
    
    return batsman_shots, bowler_shots

# Main code
import pandas as pd

# Load data
data = pd.read_csv('/Users/shiwaditya./Desktop/CCNLP/IPL2018.csv')

# Define a knowledge base of cricket terms related to batting
batting_terms = ['drives', 'cuts', 'pulls', 'nudges', 'squeezes', 'flicks', 'glances', 'sweeps', 'slog', 'lofts', 'edges', 'defends', 'across the line', 'agricultural shot', 'anchor', 'attacking shot', 'back foot shot', 'biffer', 'block', 'blocker', 'carry the bat', 'cartwheel', 'caught', 'caught and bowled', 'caught behind', 'centurion', 'century', 'charge', 'chest on', 'chop on', 'club', 'come to the crease', 'contrived circumstances', 'cow shot', 'cross-bat shot', 'cross the rope', 'reverse sweep', 'cut', 'cut shot', 'drive', 'full blooded', 'hook', 'late cut', 'pull', 'pull shot', 'square-cut', 'sweep', 'on-drive', 'off-drive', 'cover drive', 'dilscoop', 'dolly', 'duck', 'golden duck', 'leg glance', 'lolly', 'out', 'textbook shot', 'ton', 'top edge', 'uppish', 'upper cut', 'waft']

# Define a knowledge base of cricket terms related to bowling
bowling_terms = ['bowled', 'shaping', 'beats', 'yorker', 'bouncer', 'action', 'all out', 'arm ball', 'around the wicket', 'away swing', 'back foot', 'back foot contact', 'back spin', 'badger', 'ball tampering', 'ball tracking', 'bang (it) in', 'bat-pad', 'bend the back', 'bite', 'bodyline', 'bounce out', 'bowl-out', 'bowling action', 'bowling analysis', 'bowling at the death', 'bowling average', 'brace', 'bumper', 'cafeteria bowling', 'carrom ball', 'castled', 'caught and bowled', 'chin music', 'chinaman', 'chinese cut', 'clean bowled', 'creeper', 'daisy cutter', 'declaration', 'dibbly-dobbly', 'doosra', 'edge', 'fast bowler', 'ferret', 'finger spinner', 'flipper', 'follow-on', 'full toss', 'googly', 'hit wicket', 'inswinger', 'jaffa', 'leg break', 'leg cutter', 'leg theory', 'leg before wicket (lbw)', 'long hop', 'maiden over', 'no ball', 'off break', 'off side', 'off spinner', 'overpitched', 'pace bowler', 'reverse swing', 'seam', 'seamer', 'shooter', 'short leg', 'silly mid-off', 'silly mid-on', 'sticky wicket', 'stump', 'tape ball', 'teesra', 'third man', 'throwing', 'top spin', 'toe-crusher', 'twelfth man', 'unplayable delivery', 'very fine leg', 'wag', 'wagon wheel', 'wearing wicket', 'white ball', 'wicket maiden', 'wicket-to-wicket', 'worm', 'wrist spin', 'wrong foot', 'wrong footed', 'wrong', 'yorker']

# Calculate runs and wickets
batsman_runs = defaultdict(int)
bowler_wickets = defaultdict(int)

for _, row in data.iterrows():
    runs, wicket = extract_runs_wickets(str(row['long_text']))
    bowler, batsman = extract_batsman_bowler(row['short_text'])
    batsman_runs[batsman] += runs
    if wicket:
        bowler_wickets[bowler] += 1

# Print runs and wickets
print("Batsman Runs:")
for batsman, runs in sorted(batsman_runs.items()):
    print(f"{batsman}: {runs}")

print("\nBowler Wickets:")
for bowler, wickets in sorted(bowler_wickets.items()):
    print(f"{bowler}: {wickets}")

# Calculate shots played
batsman_shots, bowler_shots = calculate_shots(data, batting_terms, bowling_terms)

# Print shots played
print("\nBatsman Shots:")
for batsman, shots in sorted(batsman_shots.items()):
    print(f"{batsman}: {', '.join(set(shots))}")

print("\nBowler Shots:")
for bowler, shots in sorted(bowler_shots.items()):
    print(f"{bowler}: {', '.join(set(shots))}")
# Out:
# Batsman Runs:
# AB: 0
# Abhishek: 0
# Agarwal: 0
# Ali: 24
# Anderson: 0
# Anureet: 0
# Archer: 0
# Ashwin: 0
# Axar Patel: 0
# Barinder Sran: 0
# Basil: 0
# Bhui: 0
# Bhuvneshwar: 0
# Billings: 0
# Binny: 0
# Boult: 0
# Brathwaite: 0
# Bravo: 0
# Bumrah: 0
# Buttler: 144
# Chahal: 0
# Chahar: 0
# Chawla: 0
# Chopra: 0
# Christian: 0
# Cutting: 28
# Dananjaya: 0
# Dhoni: 0
# Duminy: 0
# Finch: 0
# Gambhir: 0
# Gayle: 0
# Gill: 32
# Gopal: 0
# Goswami: 0
# Gowtham: 56
# Grandhomme: 0
# Hales: 0
# Harbhajan: 0
# Hooda: 0
# Ishan: 0
# Iyer: 0
# JPR Scantlebury-Searles: 0
# Jadeja: 0
# Jadhav: 0
# Johnson: 110
# Karthik: 26
# Kaul: 0
# Khan: 0
# Klaasen: 0
# Kohli: 92
# Krunal: 0
# Kuldeep: 0
# Kulkarni: 0
# Laughlin: 128
# Lewis: 0
# Lomror: 0
# Lynn: 0
# M Nabi: 0
# Mandeep: 70
# Markande: 0
# Maxwell: 94
# McClenaghan: 0
# McCullum: 26
# Miller: 0
# Mishra: 0
# Morris: 20
# Mujeeb: 0
# Munro: 0
# Mustafizur: 0
# Nadeem: 0
# Nair: 0
# Narine: 0
# Nath: 0
# Negi: 0
# Ojha: 0
# Pandey: 0
# Pandya: 34
# Pant: 316
# Patel: 0
# Pathan: 0
# Plunkett: 0
# Pollard: 0
# Prasidh: 0
# Rahane: 0
# Rahul: 1030
# Raina: 0
# Rajpoot: 0
# Rana: 0
# Rashid Khan: 0
# Rayudu: 800
# Rohit Sharma: 0
# Roy: 0
# Russell: 0
# S: 0
# S Dhawan: 0
# Saha: 0
# Samson: 0
# Sandeep: 0
# Sangwan: 0
# Shakib: 0
# Shami: 0
# Shankar: 0
# Sharma: 0
# Shaw: 0
# Shivam Mavi: 0
# Shorey: 0
# Short: 0
# Singh: 0
# Siraj: 0
# Sodhi: 0
# Southee: 0
# Stanlake: 0
# Sundar: 0
# Tahir: 0
# Tewatia: 0
# Thakur: 0
# Tiwary: 0
# Tom Curran: 0
# Tripathi: 0
# Tye: 0
# Unadkat: 0
# Uthappa: 8000
# Vijay: 0
# Vinay: 0
# Vohra: 0
# Watson: 0
# Williamson: 1000
# Woakes: 0
# Wood: 0
# Yadav: 24
# Yuvraj: 0
# de Kock: 0
# du Plessis: 0
# inis: 40
# kes: 0
#
# Bowler Wickets:
# Ahmed: 1
# Ali: 8
# Anderson: 8
# Anureet: 4
# Archer: 25
# Ashwin: 39
# Asif: 5
# Avesh Khan: 16
# Axar Patel: 14
# Barinder Sran: 17
# Basil: 11
# Bhuvneshwar: 26
# Binny: 2
# Boult: 36
# Brathwaite: 5
# Bravo: 46
# Bumrah: 27
# Chahal: 35
# Chahar: 22
# Chawla: 33
# Christian: 3
# Cutting: 9
# Dala: 1
# Dananjaya: 1
# Duminy: 1
# Gopal: 25
# Gowtham: 19
# Grandhomme: 7
# Harbhajan: 29
# Hooda: 1
# JPR Scantlebury-Searles: 4
# Jadeja: 23
# Johnson: 7
# Jordan: 1
# Karn: 5
# Kaul: 41
# Khejroliya: 5
# Krunal: 32
# Kuldeep: 36
# Kulkarni: 14
# Lamichhane: 3
# Laughlin: 12
# Lomror: 1
# M Nabi: 4
# Markande: 36
# Maxwell: 11
# McClenaghan: 31
# Mishra: 18
# Morris: 5
# Mujeeb: 25
# Mustafizur: 14
# Nadeem: 6
# Narine: 31
# Negi: 3
# Ngidi: 15
# Pandya: 25
# Patel: 9
# Pathan: 1
# Plunkett: 7
# Prasidh: 18
# Rajpoot: 12
# Rana: 5
# Rashid Khan: 32
# Russell: 21
# S: 29
# Sandeep: 30
# Shakib: 42
# Shami: 7
# Shankar: 2
# Sharma: 23
# Shivam Mavi: 19
# Short: 2
# Siraj: 24
# Sodhi: 17
# Southee: 27
# Stanlake: 8
# Sundar: 9
# Tahir: 12
# Tewatia: 15
# Thakur: 39
# Tiwary: 1
# Tom Curran: 6
# Tye: 43
# Unadkat: 39
# Vinay: 1
# Watson: 15
# Willey: 7
# Woakes: 11
# Wood: 1
# Yadav: 30
# Yuvraj: 1
#
# Batsman Shots:
# AB: pull shot, hook, cut, century, squeezes, upper cut, sweeps, cuts, slog, lofts, edges, reverse sweep, club, cover drive, sweep, drives, pulls, pull, block, defends, drive, ton, top edge, out
# Abhishek: drive, slog, ton, cut, drives, lofts, top edge, squeezes, out, flicks, pull
# Agarwal: drive, cover drive, slog, dolly, ton, cut, sweep, edges, pulls, squeezes, out, pull, cuts, leg glance, block
# Ali: drive, slog, cut, sweep, lofts, pulls, out, flicks, pull, cuts
# Anderson: drive, slog, charge, pull shot, cut, drives, pulls, out, flicks, pull, cuts, block, across the line
# Anureet: defends, sweep
# Archer: slog, cut, pulls, top edge, out, duck, pull, defends
# Ashwin: drive, slog, caught, cut, sweep, drives, lofts, pulls, out, duck, flicks, pull, block, defends
# Axar Patel: drive, caught, uppish, cut, sweep, lofts, top edge, out, pull, cuts, block, across the line
# Barinder Sran: slog, cut, cut shot, pulls, out, pull, block
# Basil: cut, out
# Bhui: duck, defends, cut, out
# Bhuvneshwar: drive, caught, cut, out, pull
# Billings: drive, slog, ton, on-drive, caught, cut, sweep, pulls, out, flicks, pull, cuts, across the line
# Binny: drive, caught, cut, sweep, drives, cut shot, edges, top edge, out, flicks, nudges, pull, block, defends, across the line
# Boult: block, out
# Brathwaite: drive, caught, slog, cut, sweep, top edge, out, glances, caught behind, flicks, pull, block, defends
# Bravo: waft, hook, cut, squeezes, cuts, slog, lofts, edges, club, uppish, sweep, drives, pulls, flicks, pull, block, across the line, drive, out
# Bumrah: drive, slog, out
# Buttler: waft, pull shot, cut, squeezes, upper cut, sweeps, cuts, slog, lofts, reverse sweep, late cut, sweep, drives, pulls, flicks, pull, block, drive, ton, top edge, out
# Chahal: out
# Chahar: drive, slog, uppish, cut, sweep, drives, out, flicks, sweeps, across the line
# Chawla: drive, slog, cut, sweep, drives, squeezes, out, block, defends, uppish
# Chopra: nudges, out
# Christian: drive, slog, squeezes, out, block
# Cutting: drive, slog, cut, sweep, lofts, out, duck, sweeps, pull, across the line
# Dananjaya: out
# Dhoni: hook, cut, century, squeezes, upper cut, glances, sweeps, cuts, slog, charge, lofts, edges, uppish, sweep, drives, pulls, flicks, pull, block, defends, drive, caught, dolly, out
# Duminy: drive, slog, cut, sweep, drives, pulls, out, sweeps, pull, cuts, block, defends
# Finch: drive, slog, caught, hook, cut, sweep, top edge, out, duck, sweeps, pull, cuts, block, defends, across the line, golden duck
# Gambhir: drive, slog, pull shot, cut, sweep, drives, lofts, edges, out, sweeps, pull, across the line, defends, uppish
# Gayle: pull shot, hook, cut, century, squeezes, duck, sweeps, slog, edges, uppish, sweep, drives, pulls, flicks, nudges, pull, block, defends, across the line, drive, cut shot, top edge, out
# Gill: drive, cover drive, caught, ton, cut, sweep, drives, cut shot, pulls, top edge, out, reverse sweep, duck, glances, pull, cuts, block, defends
# Gopal: drive, cover drive, late cut, cut, sweep, out, pull, cuts
# Goswami: drive, slog, late cut, hook, cut, sweep, pulls, out, reverse sweep, pull
# Gowtham: drive, slog, caught, cut, sweep, edges, top edge, squeezes, out, caught behind, flicks, pull, cuts, across the line
# Grandhomme: drive, slog, ton, cut, sweep, drives, lofts, pulls, squeezes, out, pull, cuts, club, block, uppish
# Hales: cut, century, squeezes, upper cut, sweeps, cuts, slog, charge, sweep, drives, pulls, nudges, pull, block, defends, across the line, drive, ton, out
# Harbhajan: drive, slog, cut, pulls, out, pull
# Hooda: drive, slog, pull shot, cut, sweep, drives, pulls, reverse sweep, out, flicks, pull, cuts, across the line
# Ishan: drive, slog, ton, cut, sweep, drives, edges, pulls, squeezes, out, reverse sweep, duck, sweeps, pull, cuts, block, defends, across the line
# Iyer: waft, cut, squeezes, upper cut, glances, duck, slog, on-drive, edges, uppish, cover drive, late cut, sweep, drives, pulls, flicks, nudges, pull, block, defends, across the line, drive, out
# JPR Scantlebury-Searles: out, slog, pull, sweep
# Jadeja: drive, caught, slog, charge, cut, sweep, lofts, edges, pulls, squeezes, out, nudges, caught and bowled, pull, cuts, block, across the line
# Jadhav: sweep, cut, out
# Johnson: drive, slog, caught, top edge, out, pull
# Karthik: pull shot, cut, century, squeezes, glances, sweeps, cuts, slog, lofts, edges, reverse sweep, uppish, cover drive, late cut, sweep, drives, pulls, flicks, nudges, pull, block, defends, across the line, drive, ton, out
# Kaul: drive, cut, squeezes, out
# Khan: drive, slog, late cut, cut, sweep, edges, out, glances, pull, cuts, defends
# Klaasen: drive, slog, cut, sweep, edges, reverse sweep, out, pull, block, defends
# Kohli: pull shot, hook, cut, duck, cuts, slog, charge, lofts, chop on, edges, uppish, cover drive, late cut, sweep, drives, pulls, flicks, nudges, pull, block, defends, across the line, drive, caught, ton, top edge, out, caught behind
# Krunal: hook, cut, squeezes, duck, glances, sweeps, slog, late cut, sweep, drives, pulls, flicks, pull, block, defends, across the line, drive, caught, ton, cut shot, out, caught behind
# Kuldeep: drive, slog, cut, sweep, top edge, reverse sweep, out, sweeps, block, defends
# Kulkarni: sweep, hook, out
# Laughlin: ton, cut, upper cut, out, pull
# Lewis: cut, squeezes, duck, sweeps, slog, lofts, edges, golden duck, sweep, drives, pulls, flicks, pull, block, defends, across the line, drive, ton, top edge, out
# Lomror: drive, slog, cut, sweep, lofts, out, reverse sweep, pull
# Lynn: waft, pull shot, cut, squeezes, duck, sweeps, cuts, slog, lofts, edges, club, cover drive, sweep, drives, pulls, flicks, nudges, pull, block, defends, across the line, drive, caught, ton, cut shot, top edge, out, caught behind
# M Nabi: drive, sweep, pulls, top edge, out, pull
# Mandeep: drive, slog, late cut, cut, sweep, drives, century, pulls, out, reverse sweep, flicks, sweeps, nudges, pull, cuts, across the line, block, uppish
# Markande: drive, cut, out
# Maxwell: drive, slog, caught, cut, sweep, top edge, squeezes, reverse sweep, out, flicks, duck, nudges, pull, block, defends, across the line
# McClenaghan: slog, sweep, out, sweeps, pull, block
# McCullum: drive, slog, charge, hook, cut, sweep, pulls, top edge, out, reverse sweep, duck, sweeps, pull, block, defends
# Miller: drive, slog, cut, sweep, drives, top edge, out, duck, pull, cuts, block, defends, across the line
# Mishra: out
# Morris: drive, cut, drives, pulls, squeezes, out, pull, block
# Mujeeb: hook, cut, sweep, pulls, out, reverse sweep, sweeps, pull, cuts
# Munro: drive, slog, cut, sweep, drives, pulls, out, duck, reverse sweep, pull, cuts, block, across the line, golden duck
# Mustafizur: pull
# Nadeem: drive, cut, sweep, out, flicks
# Nair: pull shot, cut, century, squeezes, sweeps, lofts, edges, reverse sweep, uppish, sweep, drives, pulls, flicks, nudges, pull, block, defends, across the line, drive, cut shot, top edge, out
# Narine: hook, cut, duck, sweeps, slog, lofts, edges, club, uppish, sweep, drives, pulls, flicks, pull, block, defends, drive, top edge, out
# Nath: drive, sweep, drives, reverse sweep, out, pull
# Negi: late cut, cut, pulls, squeezes, out, pull, cuts
# Ojha: out
# Pandey: pull shot, cut, century, squeezes, glances, duck, sweeps, cuts, slog, charge, edges, uppish, late cut, sweep, drives, pulls, flicks, nudges, pull, block, defends, across the line, drive, dolly, ton, out
# Pandya: hook, cut, squeezes, duck, sweeps, cuts, slog, on-drive, edges, uppish, sweep, pulls, flicks, pull, block, defends, drive, caught, ton, top edge, out
# Pant: pull shot, hook, cut, century, duck, sweeps, cuts, slog, charge, lofts, edges, reverse sweep, uppish, late cut, sweep, drives, pulls, flicks, nudges, pull, block, defends, across the line, drive, caught, ton, cut shot, top edge, out, caught behind
# Patel: drive, cover drive, slog, waft, uppish, hook, cut, sweep, drives, edges, pulls, squeezes, out, flicks, sweeps, pull, across the line
# Pathan: hook, cut, upper cut, duck, sweeps, cuts, slog, edges, late cut, sweep, drives, pulls, flicks, nudges, pull, block, across the line, drive, out
# Plunkett: late cut, cut, out, duck, golden duck
# Pollard: drive, slog, late cut, ton, charge, cut, sweep, lofts, pulls, squeezes, out, duck, flicks, pull, block, defends
# Prasidh: block, out
# Rahane: waft, hook, cut, sweeps, cuts, slog, charge, edges, reverse sweep, caught and bowled, uppish, sweep, drives, pulls, flicks, nudges, pull, block, defends, across the line, drive, caught, out
# Rahul: pull shot, hook, cut, century, upper cut, sweeps, cuts, slog, charge, on-drive, lofts, edges, reverse sweep, uppish, cover drive, late cut, sweep, drives, pulls, flicks, nudges, pull, block, defends, across the line, drive, cut shot, top edge, out
# Raina: hook, cut, century, squeezes, duck, glances, cuts, slog, lofts, edges, caught and bowled, uppish, cover drive, sweep, drives, pulls, flicks, nudges, pull, block, defends, across the line, drive, caught, out, caught behind
# Rajpoot: slog, cut, pull, out
# Rana: hook, cut, duck, sweeps, cuts, slog, lofts, edges, reverse sweep, uppish, cover drive, sweep, drives, pulls, flicks, pull, block, defends, across the line, drive, caught, out, caught behind
# Rashid Khan: slog, caught, sweep, lofts, edges, pulls, squeezes, out, pull, across the line
# Rayudu: hook, cut, century, squeezes, glances, duck, sweeps, cuts, slog, charge, lofts, edges, reverse sweep, club, sweep, drives, pulls, flicks, pull, block, defends, across the line, drive, out
# Rohit Sharma: cut, century, duck, sweeps, cuts, slog, lofts, edges, uppish, sweep, drives, pulls, flicks, pull, block, defends, drive, dolly, caught, out, caught behind
# Roy: drive, cover drive, slog, cut, sweep, drives, edges, pulls, out, reverse sweep, flicks, pull, cuts, across the line
# Russell: cut, century, squeezes, upper cut, duck, cuts, slog, lofts, edges, sweep, drives, pulls, flicks, pull, block, defends, drive, ton, cut shot, top edge, out
# S: hook, cut, sweeps, slog, lofts, edges, reverse sweep, uppish, sweep, drives, pulls, flicks, pull, block, defends, across the line, drive, caught, ton, cut shot, out
# S Dhawan: hook, cut, century, squeezes, upper cut, duck, sweeps, cuts, leg glance, slog, charge, lofts, edges, uppish, cover drive, late cut, sweep, drives, pulls, flicks, nudges, pull, block, defends, drive, ton, top edge, out
# Saha: hook, cut, squeezes, upper cut, duck, cuts, slog, edges, uppish, cover drive, sweep, drives, pulls, nudges, pull, block, anchor, drive, top edge, out
# Samson: waft, pull shot, hook, cut, century, squeezes, glances, sweeps, cuts, slog, lofts, uppish, late cut, sweep, drives, pulls, flicks, pull, block, defends, drive, caught, top edge, out
# Sandeep: block, cut, out
# Sangwan: across the line, out
# Shakib: cut, squeezes, upper cut, sweeps, cuts, slog, charge, edges, sweep, drives, pulls, flicks, pull, block, defends, across the line, drive, caught, dolly, cut shot, top edge, out
# Shami: slog, top edge, cut, out
# Shankar: hook, cut, squeezes, duck, sweeps, cuts, slog, lofts, edges, sweep, pulls, flicks, nudges, pull, block, defends, across the line, drive, caught, out, caught behind
# Sharma: drive, cut, sweep, out, duck, uppish
# Shaw: cut, century, duck, sweeps, slog, on-drive, lofts, sweep, drives, pulls, flicks, nudges, pull, block, defends, across the line, drive, dolly, top edge, out
# Shivam Mavi: out, edges, cut, sweep
# Shorey: drive, cut, drives, edges, out, pull, cuts
# Short: drive, slog, caught, pull shot, cut, sweep, pulls, out, caught behind, flicks, pull, block, defends
# Singh: drive, cover drive, late cut, cut, sweep, drives, out, pull, cuts, defends
# Siraj: drive, slog, ton, cut, sweep, squeezes, upper cut, out, pull, block
# Sodhi: caught, edges, out, caught behind, pull, block
# Southee: drive, cut, sweep, drives, edges, pulls, out, pull, block, defends, across the line
# Stanlake: cut
# Sundar: drive, ton, cut, sweep, out, pull, defends, across the line
# Tewatia: drive, slog, cut, sweep, out, sweeps, pull, cuts
# Thakur: drive, cut, out
# Tiwary: drive, slog, caught, hook, cut, sweep, drives, top edge, out, flicks, nudges, pull, cuts, block
# Tom Curran: drive, slog, cut, drives, pulls, out, pull, cuts, block
# Tripathi: hook, cut, squeezes, sweeps, cuts, slog, on-drive, charge, lofts, uppish, cover drive, late cut, sweep, drives, pulls, nudges, pull, block, defends, across the line, drive, caught, out
# Tye: drive, slog, hook, cut, edges, out, pull, across the line
# Unadkat: drive, slog, cut, sweep, drives, edges, pulls, out, sweeps, pull, cuts, block
# Uthappa: pull shot, hook, cut, duck, sweeps, slog, on-drive, lofts, edges, reverse sweep, late cut, sweep, drives, pulls, flicks, nudges, pull, block, defends, across the line, drive, caught, ton, top edge, out, caught behind
# Vijay: pull, out
# Vinay: out
# Vohra: drive, slog, uppish, cut, sweep, drives, lofts, top edge, squeezes, out, flicks, sweeps, nudges, pull, block, across the line
# Watson: pull shot, hook, cut, century, duck, glances, sweeps, cuts, slog, chop on, edges, uppish, sweep, drives, pulls, flicks, nudges, pull, block, defends, across the line, drive, caught, ton, top edge, out
# Williamson: pull shot, hook, cut, century, squeezes, upper cut, duck, sweeps, cuts, slog, charge, lofts, edges, uppish, cover drive, late cut, sweep, drives, pulls, flicks, nudges, pull, block, defends, across the line, drive, caught, ton, cut shot, out, caught behind
# Woakes: slog, ton, pull, out
# Wood: pull, out
# Yadav: hook, cut, upper cut, glances, duck, sweeps, cuts, slog, lofts, edges, club, uppish, golden duck, cover drive, late cut, sweep, drives, pulls, flicks, pull, block, defends, across the line, drive, caught, top edge, out
# Yuvraj: drive, slog, cut, sweep, edges, pulls, out, duck, flicks, sweeps, pull, block, uppish
# de Kock: cut, squeezes, sweeps, cuts, slog, charge, lofts, edges, reverse sweep, sweep, drives, pulls, flicks, nudges, pull, block, defends, across the line, drive, ton, top edge, out
# du Plessis: drive, waft, slog, ton, charge, hook, cut, sweep, drives, lofts, edges, pulls, out, flicks, sweeps, pull, defends
# inis: drive, slog, cut, century, drives, pulls, squeezes, out, pull, across the line, block, uppish
# kes: pull shot, hook, cut, squeezes, cuts, slog, lofts, edges, uppish, sweep, drives, pulls, flicks, pull, block, defends, drive, ton, out
#
# Bowler Shots:
# Ahmed: third man, edge, bouncer, stump
# Ali: third man, edge, stump, off side
# Anderson: all out, third man, brace, back foot, bowled, yorker, off side, full toss, edge, stump
# Ankit: stump
# Anureet: all out, bouncer, third man, edge, stump
# Archer: all out, third man, bouncer, no ball, wrong, beats, back foot, bowled, around the wicket, yorker, off side, full toss, edge, shaping, stump
# Ashwin: all out, flipper, arm ball, bowled, short leg, seam, third man, back foot, around the wicket, throwing, stump, beats, yorker, action, bounce out, full toss, edge, googly, wrong, overpitched, carrom ball, off side, leg break
# Asif: third man, all out, bouncer, overpitched, back foot, full toss, edge, stump
# Avesh Khan: third man, all out, wrong, overpitched, inswinger, beats, back foot, bowled, yorker, off side, seam, full toss, edge, stump
# Axar Patel: all out, third man, arm ball, wrong, beats, back foot, yorker, off side, edge, stump
# Barinder Sran: all out, third man, bouncer, fast bowler, wrong, beats, inswinger, back foot, yorker, off side, full toss, edge, shaping, stump
# Basil: third man, all out, bouncer, wrong, back foot, bowled, around the wicket, yorker, short leg, seam, full toss, edge, stump
# Bhuvneshwar: third man, all out, bouncer, no ball, wrong, beats, inswinger, overpitched, back foot, bowled, yorker, off side, seam, full toss, edge, stump
# Binny: third man, overpitched, back foot, edge, shaping, stump
# Boult: all out, bowled, shaping, third man, no ball, back foot, around the wicket, stump, bouncer, away swing, beats, inswinger, yorker, action, full toss, edge, wrong, overpitched, off side
# Brathwaite: all out, third man, overpitched, back foot, yorker, off side, full toss, edge, stump
# Bravo: all out, bouncer, third man, brace, wrong, overpitched, beats, back foot, bowled, around the wicket, yorker, action, off side, seam, full toss, edge, stump
# Bumrah: third man, all out, bouncer, wrong, overpitched, inswinger, beats, back foot, bowled, yorker, off side, seam, full toss, edge, stump
# Chahal: third man, all out, flipper, no ball, wrong, beats, back foot, bowled, yorker, off side, seam, leg break, full toss, edge, stump, googly
# Chahar: all out, brace, bowled, seam, shaping, third man, back foot, around the wicket, stump, bouncer, fast bowler, jaffa, beats, inswinger, yorker, full toss, edge, wrong, overpitched, off side, wicket maiden
# Chawla: third man, all out, wrong, beats, overpitched, back foot, bowled, yorker, action, off side, seam, full toss, leg break, edge, stump, googly
# Christian: third man, all out, beats, overpitched, yorker, off side, full toss, edge, stump
# Cutting: third man, all out, brace, beats, overpitched, bowled, yorker, off side, full toss, edge, stump
# Dala: third man, brace, back foot, yorker, full toss, edge, stump
# Dananjaya: wrong, back foot, yorker, full toss, googly
# Duminy: stump, back foot
# Gopal: all out, third man, long hop, wrong, beats, overpitched, back foot, bowled, off side, seam, edge, stump, googly
# Gowtham: all out, third man, beats, overpitched, back foot, bowled, around the wicket, yorker, short leg, off side, full toss, edge, stump
# Grandhomme: all out, overpitched, back foot, off side, full toss, edge, stump
# Harbhajan: third man, all out, doosra, beats, back foot, bowled, yorker, off side, full toss, edge, stump
# Hooda: third man, overpitched, back foot, around the wicket, off side, edge, stump
# JPR Scantlebury-Searles: all out, third man, wag, overpitched, back foot, bowled, yorker, off side, full toss, edge, stump
# Jadeja: all out, third man, arm ball, beats, wrong, overpitched, back foot, around the wicket, action, off side, edge, stump
# Johnson: bouncer, third man, all out, beats, overpitched, back foot, around the wicket, action, yorker, off side, edge, shaping, stump
# Jordan: beats, back foot, yorker, full toss, edge, stump
# Karn: all out, third man, wag, back foot, off side, edge, stump, googly
# Kaul: all out, third man, bouncer, brace, beats, overpitched, back foot, bowled, yorker, off side, seam, full toss, edge, shaping, stump
# Khejroliya: third man, bouncer, wrong, beats, back foot, bowled, yorker, off side, full toss, edge, stump
# Krunal: all out, third man, arm ball, beats, overpitched, back foot, bowled, around the wicket, yorker, off side, full toss, edge, stump, white ball
# Kuldeep: all out, third man, wrong, beats, overpitched, back foot, bowled, around the wicket, bat-pad, yorker, caught and bowled, off side, full toss, edge, shaping, stump, googly
# Kulkarni: third man, all out, bouncer, wrong, overpitched, beats, back foot, bowled, yorker, off side, full toss, edge, stump
# Lamichhane: wrong, beats, back foot, bowled, short leg, off side, throwing, edge, stump, googly
# Laughlin: third man, all out, bouncer, wrong, beats, back foot, yorker, off side, full toss, edge, shaping, stump
# Lomror: stump, back foot
# M Nabi: third man, back foot, around the wicket, off side, stump
# Markande: third man, all out, wrong, beats, overpitched, back foot, bowled, short leg, off side, full toss, edge, stump, googly
# Maxwell: third man, beats, overpitched, back foot, bowled, around the wicket, yorker, edge, stump
# McClenaghan: bouncer, all out, third man, wrong, beats, overpitched, back foot, bowled, yorker, off side, full toss, edge, stump
# Mishra: third man, brace, wrong, beats, arm ball, back foot, bowled, yorker, seam, full toss, throwing, edge, wicket maiden, stump, googly, seamer
# Morris: all out, third man, bouncer, overpitched, beats, around the wicket, yorker, off side, leg cutter, throwing, full toss, seam, edge, stump
# Mujeeb: third man, all out, brace, flipper, wrong, beats, overpitched, back foot, bowled, short leg, carrom ball, off side, seam, yorker, full toss, edge, stump, googly
# Mustafizur: third man, all out, wag, beats, overpitched, back foot, bowled, yorker, off side, full toss, edge, stump
# Nadeem: all out, wrong, arm ball, beats, back foot, bowled, around the wicket, off side, full toss, edge, stump
# Narine: third man, all out, brace, wrong, overpitched, beats, arm ball, back foot, bowled, around the wicket, carrom ball, yorker, off side, seam, edge, stump
# Negi: third man, edge, stump, bowled
# Ngidi: third man, maiden over, all out, wrong, overpitched, beats, back foot, yorker, off side, seam, full toss, edge, stump
# Pandya: third man, bouncer, all out, wrong, overpitched, beats, back foot, bowled, wicket-to-wicket, yorker, off side, seam, full toss, edge, stump
# Patel: all out, third man, bouncer, fast bowler, wrong, overpitched, back foot, bowled, around the wicket, action, yorker, off side, seam, full toss, edge, stump
# Pathan: edge, stump, around the wicket
# Plunkett: third man, bouncer, all out, no ball, beats, overpitched, back foot, bowled, yorker, short leg, off side, seam, full toss, action, edge, stump, seamer
# Prasidh: third man, bouncer, all out, wrong, beats, overpitched, inswinger, back foot, bowled, yorker, off side, seam, full toss, edge, stump
# Rajpoot: all out, bouncer, third man, fast bowler, away swing, beats, inswinger, back foot, bowled, yorker, short leg, bounce out, off side, full toss, seam, edge, shaping, stump
# Rana: third man, back foot, action, off side, edge, stump
# Rashid Khan: third man, all out, brace, flipper, long hop, wrong, beats, overpitched, back foot, short leg, yorker, off side, action, full toss, leg break, edge, stump, googly
# Russell: all out, third man, bouncer, brace, wrong, overpitched, jaffa, beats, back foot, yorker, action, off side, full toss, edge, shaping, stump
# S: third man, bouncer, all out, wrong, overpitched, beats, back foot, bowled, yorker, action, off side, seam, full toss, short leg, edge, wicket maiden, stump
# Sandeep: all out, bouncer, third man, brace, wrong, overpitched, beats, inswinger, back foot, bowled, around the wicket, yorker, caught and bowled, off side, full toss, edge, shaping, stump
# Sangwan: edge, stump
# Shakib: all out, third man, wrong, overpitched, arm ball, beats, back foot, bowled, short leg, yorker, off side, seam, full toss, edge, stump
# Shami: bouncer, all out, third man, beats, overpitched, bowled, yorker, off side, full toss, edge, stump
# Shankar: third man, back foot, full toss, edge, shaping, stump
# Sharma: third man, bouncer, all out, wrong, beats, back foot, bowled, around the wicket, yorker, off side, full toss, edge, stump
# Shivam Mavi: third man, all out, bite, bouncer, fast bowler, beats, overpitched, back foot, yorker, off side, seam, full toss, edge, stump
# Short: all out, edge, stump, googly
# Siraj: bouncer, all out, third man, no ball, beats, overpitched, back foot, bowled, yorker, bounce out, seam, full toss, off side, edge, stump
# Sodhi: third man, wrong, beats, back foot, bat-pad, off side, edge, stump, googly
# Southee: third man, bouncer, all out, wrong, beats, overpitched, back foot, bowled, yorker, short leg, off side, seam, full toss, edge, shaping, stump
# Stanlake: third man, all out, bouncer, wrong, overpitched, back foot, around the wicket, yorker, off side, full toss, edge, stump
# Sundar: third man, fast bowler, back foot, bowled, around the wicket, off side, full toss, edge, stump
# Tahir: third man, all out, flipper, wrong, beats, overpitched, back foot, short leg, off side, full toss, edge, stump, googly
# Tewatia: third man, all out, wrong, overpitched, beats, back foot, bowled, off side, leg break, full toss, edge, stump, googly
# Thakur: third man, all out, bouncer, wrong, beats, overpitched, back foot, bowled, yorker, off side, full toss, throwing, edge, shaping, stump
# Tiwary: action, stump, around the wicket
# Tom Curran: third man, all out, no ball, wrong, overpitched, bowled, yorker, full toss, edge, stump
# Tye: bouncer, all out, third man, wrong, overpitched, beats, back foot, bowled, yorker, off side, seam, full toss, bounce out, edge, shaping, stump
# Unadkat: all out, third man, bouncer, wrong, beats, overpitched, back foot, bowled, around the wicket, yorker, action, off side, seam, full toss, caught and bowled, edge, stump
# Vinay: all out, third man, yorker, full toss, edge, stump
# Watson: third man, all out, bouncer, beats, overpitched, back foot, short leg, yorker, off side, full toss, edge, stump
# Willey: third man, all out, beats, inswinger, yorker, action, off side, edge, stump
# Woakes: all out, third man, bouncer, wrong, beats, back foot, bowled, yorker, off side, seam, full toss, edge, stump
# Wood: third man, bouncer, overpitched, back foot, yorker, off side, stump
# Yadav: all out, bowled, short leg, seam, shaping, third man, back foot, around the wicket, clean bowled, stump, bouncer, fast bowler, away swing, beats, yorker, action, full toss, edge, wrong, overpitched, off side
# Yuvraj: edge
